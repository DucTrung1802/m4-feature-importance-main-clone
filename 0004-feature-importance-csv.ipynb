# %%
import pickle
import glob
from utils import *
import pandas as pd
# Out:
# /opt/conda/envs/Base/lib/python3.9/site-packages/sktime/utils/validation/series.py:21: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.Int64Index, pd.RangeIndex, pd.PeriodIndex, pd.DatetimeIndex)

# %%
fdf = get_problem_features(glob.glob('features/TSFresh.csv'))
fdf = fdf.pipe(drop_nan_and_non_unique_columns)
all_columns = list(fdf.columns)
# Out:
# get_problem_features took=0:01:19.968911 shape=(100000, 789)
# drop_nan_and_non_unique_columns took=0:00:07.605689 shape=(100000, 323)

# %%
files = glob.glob('feature_importance/*.p')

# %%
df_dict = {x: [] for x in ['ml_algorithm', 'forecasting_algorithm', 'run', 'feature_importance_method'] + all_columns}

for file in files:
    algo = re_find('m_(.+?)_f_', file)
    run = re_find('r_(.+?)_m_', file)
    fe = re_find('_f_(.+?)\.p', file)
    
    meta = pickle.load(open(file, 'rb'))
    
    if 'shap' in fe:
        fe = 'shap'
        
    for forecasting_algo, perf_list in meta.items():
        df_dict['ml_algorithm'].append(algo)
        df_dict['forecasting_algorithm'].append(forecasting_algo)
        df_dict['run'].append(run)
        df_dict['feature_importance_method'].append(fe)
        
        perf_dict = {b:a for a, b in perf_list}
        
        for feature in all_columns:
            if feature in perf_dict:
                df_dict[feature].append(perf_dict[feature])
            else:
                df_dict[feature].append(None)

# %%
dffe = pd.DataFrame(df_dict)
dffe.to_csv('feature_importance/merged_feature_importance.csv')

# %%
dffe
# Out:
#                               ml_algorithm forecasting_algorithm run  \
# 0      M4RandomForestSingleOutputRegressor                   106  24
# 1                  M4RandomForestRegressor                   256  18
# 2                    M4DummyMeanRegression                   243   5
# 3                           M4XGBRegressor                 Theta  12
# 4                           M4XGBRegressor                   078  15
# ...                                    ...                   ...  ..
# 29275              M4RandomForestRegressor                sNaive   3
# 29276                M4DummyMeanRegression                   078   6
# 29277                       M4XGBRegressor                   219  12
# 29278                M4DummyMeanRegression                   126   5
# 29279              M4RandomForestRegressor                sNaive  29
#
#       feature_importance_method  value__has_duplicate_max  \
# 0                          shap                  0.000287
# 1                          shap                  0.000317
# 2                          shap                  0.000000
# 3                          shap                  0.000323
# 4                          shap                  0.000292
# ...                         ...                       ...
# 29275                      shap                  0.000301
# 29276                      shap                  0.000000
# 29277                      shap                  0.000586
# 29278                      shap                  0.000000
# 29279                      shap                  0.000303
#
#       value__has_duplicate_min value__has_duplicate value__sum_values  \
# 0                         None                 None              None
# 1                         None                 None              None
# 2                         None                 None              None
# 3                         None                 None              None
# 4                         None                 None              None
# ...                        ...                  ...               ...
# 29275                     None                 None              None
# 29276                     None                 None              None
# 29277                     None                 None              None
# 29278                     None                 None              None
# 29279                     None                 None              None
#
#       value__abs_energy value__mean_abs_change  ...  \
# 0                  None                   None  ...
# 1                  None                   None  ...
# 2                  None                   None  ...
# 3                  None                   None  ...
# 4                  None                   None  ...
# ...                 ...                    ...  ...
# 29275              None                   None  ...
# 29276              None                   None  ...
# 29277              None                   None  ...
# 29278              None                   None  ...
# 29279              None                   None  ...
#
#       value__lempel_ziv_complexity__bins_3  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 29275                                 None
# 29276                                 None
# 29277                                 None
# 29278                                 None
# 29279                                 None
#
#        value__lempel_ziv_complexity__bins_5  \
# 0                                      None
# 1                                      None
# 2                                      None
# 3                                      None
# 4                                      None
# ...                                     ...
# 29275                                  None
# 29276                                  None
# 29277                                  None
# 29278                                  None
# 29279                                  None
#
#        value__lempel_ziv_complexity__bins_10  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 29275                                   None
# 29276                                   None
# 29277                                   None
# 29278                                   None
# 29279                                   None
#
#       value__lempel_ziv_complexity__bins_100  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 29275                                   None
# 29276                                   None
# 29277                                   None
# 29278                                   None
# 29279                                   None
#
#        value__permutation_entropy__dimension_3__tau_1  \
# 0                                            0.004303
# 1                                            0.003058
# 2                                            0.000000
# 3                                            0.004436
# 4                                            0.004712
# ...                                               ...
# 29275                                        0.002781
# 29276                                        0.000000
# 29277                                        0.004665
# 29278                                        0.000000
# 29279                                        0.003165
#
#        value__permutation_entropy__dimension_4__tau_1  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ...                                               ...
# 29275                                            None
# 29276                                            None
# 29277                                            None
# 29278                                            None
# 29279                                            None
#
#       value__permutation_entropy__dimension_5__tau_1  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 29275                                           None
# 29276                                           None
# 29277                                           None
# 29278                                           None
# 29279                                           None
#
#       value__permutation_entropy__dimension_6__tau_1  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 29275                                           None
# 29276                                           None
# 29277                                           None
# 29278                                           None
# 29279                                           None
#
#        value__permutation_entropy__dimension_7__tau_1  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ...                                               ...
# 29275                                            None
# 29276                                            None
# 29277                                            None
# 29278                                            None
# 29279                                            None
#
#       value__mean_n_absolute_max__number_of_maxima_7
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# ...                                              ...
# 29275                                           None
# 29276                                           None
# 29277                                           None
# 29278                                           None
# 29279                                           None
#
# [29280 rows x 327 columns]

# %%
check_if_complete_df = dffe.groupby(['ml_algorithm', 'forecasting_algorithm', 'feature_importance_method']).count().reset_index()

# %%
check_if_complete_df.query("run!=30")
# Out:
# Empty DataFrame
# Columns: [ml_algorithm, forecasting_algorithm, feature_importance_method, run, value__has_duplicate_max, value__has_duplicate_min, value__has_duplicate, value__sum_values, value__abs_energy, value__mean_abs_change, value__mean_change, value__mean_second_derivative_central, value__median, value__mean, value__length, value__standard_deviation, value__variation_coefficient, value__variance, value__skewness, value__kurtosis, value__root_mean_square, value__absolute_sum_of_changes, value__longest_strike_below_mean, value__longest_strike_above_mean, value__count_above_mean, value__count_below_mean, value__last_location_of_maximum, value__first_location_of_maximum, value__last_location_of_minimum, value__first_location_of_minimum, value__percentage_of_reoccurring_values_to_all_values, value__percentage_of_reoccurring_datapoints_to_all_datapoints, value__sum_of_reoccurring_values, value__sum_of_reoccurring_data_points, value__ratio_value_number_to_time_series_length, value__maximum, value__absolute_maximum, value__minimum, value__benford_correlation, value__time_reversal_asymmetry_statistic__lag_1, value__time_reversal_asymmetry_statistic__lag_2, value__time_reversal_asymmetry_statistic__lag_3, value__c3__lag_1, value__c3__lag_2, value__c3__lag_3, value__cid_ce__normalize_True, value__cid_ce__normalize_False, value__symmetry_looking__r_0.05, value__symmetry_looking__r_0.1, value__symmetry_looking__r_0.15000000000000002, value__symmetry_looking__r_0.2, value__symmetry_looking__r_0.25, value__symmetry_looking__r_0.30000000000000004, value__symmetry_looking__r_0.35000000000000003, value__symmetry_looking__r_0.4, value__symmetry_looking__r_0.45, value__large_standard_deviation__r_0.05, value__large_standard_deviation__r_0.1, value__large_standard_deviation__r_0.15000000000000002, value__large_standard_deviation__r_0.2, value__large_standard_deviation__r_0.25, value__large_standard_deviation__r_0.30000000000000004, value__large_standard_deviation__r_0.35000000000000003, value__large_standard_deviation__r_0.4, value__large_standard_deviation__r_0.45, value__quantile__q_0.1, value__quantile__q_0.2, value__quantile__q_0.3, value__quantile__q_0.4, value__quantile__q_0.6, value__quantile__q_0.7, value__quantile__q_0.8, value__quantile__q_0.9, value__autocorrelation__lag_0, value__autocorrelation__lag_1, value__autocorrelation__lag_2, value__autocorrelation__lag_3, value__autocorrelation__lag_4, value__autocorrelation__lag_5, value__autocorrelation__lag_6, value__autocorrelation__lag_7, value__autocorrelation__lag_8, value__autocorrelation__lag_9, value__agg_autocorrelation__f_agg_"mean"__maxlag_40, value__agg_autocorrelation__f_agg_"median"__maxlag_40, value__agg_autocorrelation__f_agg_"var"__maxlag_40, value__partial_autocorrelation__lag_1, value__partial_autocorrelation__lag_2, value__partial_autocorrelation__lag_3, value__partial_autocorrelation__lag_4, value__partial_autocorrelation__lag_5, value__number_cwt_peaks__n_1, value__number_cwt_peaks__n_5, value__number_peaks__n_1, value__number_peaks__n_3, value__number_peaks__n_5, value__number_peaks__n_10, value__number_peaks__n_50, value__binned_entropy__max_bins_10, value__index_mass_quantile__q_0.1, ...]
# Index: []
#
# [0 rows x 327 columns]

# %%
check_if_complete_df['run'].mean()
# Out:
# 30.0

# %%
check_if_complete_df.sort_values(['run'])
# Out:
#                 ml_algorithm forecasting_algorithm feature_importance_method  \
# 0      M4DummyMeanRegression                   005               permutation
# 643           M4XGBRegressor                   104              xgboost-gain
# 644           M4XGBRegressor                   104       xgboost-total_cover
# 645           M4XGBRegressor                   104        xgboost-total_gain
# 646           M4XGBRegressor                   104            xgboost-weight
# ..                       ...                   ...                       ...
# 330  M4RandomForestRegressor                   252               permutation
# 331  M4RandomForestRegressor                   252                      shap
# 332  M4RandomForestRegressor                   253               permutation
# 334  M4RandomForestRegressor                   255               permutation
# 975           M4XGBRegressor                sNaive            xgboost-weight
#
#      run  value__has_duplicate_max  value__has_duplicate_min  \
# 0     30                        30                         0
# 643   30                        30                         0
# 644   30                        30                         0
# 645   30                        30                         0
# 646   30                        30                         0
# ..   ...                       ...                       ...
# 330   30                        30                         0
# 331   30                        30                         0
# 332   30                        30                         0
# 334   30                        30                         0
# 975   30                        30                         0
#
#      value__has_duplicate  value__sum_values  value__abs_energy  \
# 0                       0                  0                  0
# 643                     0                  0                  0
# 644                     0                  0                  0
# 645                     0                  0                  0
# 646                     0                  0                  0
# ..                    ...                ...                ...
# 330                     0                  0                  0
# 331                     0                  0                  0
# 332                     0                  0                  0
# 334                     0                  0                  0
# 975                     0                  0                  0
#
#      value__mean_abs_change  ...  value__lempel_ziv_complexity__bins_3  \
# 0                         0  ...                                     0
# 643                       0  ...                                     0
# 644                       0  ...                                     0
# 645                       0  ...                                     0
# 646                       0  ...                                     0
# ..                      ...  ...                                   ...
# 330                       0  ...                                     0
# 331                       0  ...                                     0
# 332                       0  ...                                     0
# 334                       0  ...                                     0
# 975                       0  ...                                     0
#
#      value__lempel_ziv_complexity__bins_5  \
# 0                                       0
# 643                                     0
# 644                                     0
# 645                                     0
# 646                                     0
# ..                                    ...
# 330                                     0
# 331                                     0
# 332                                     0
# 334                                     0
# 975                                     0
#
#      value__lempel_ziv_complexity__bins_10  \
# 0                                        0
# 643                                      0
# 644                                      0
# 645                                      0
# 646                                      0
# ..                                     ...
# 330                                      0
# 331                                      0
# 332                                      0
# 334                                      0
# 975                                      0
#
#      value__lempel_ziv_complexity__bins_100  \
# 0                                         0
# 643                                       0
# 644                                       0
# 645                                       0
# 646                                       0
# ..                                      ...
# 330                                       0
# 331                                       0
# 332                                       0
# 334                                       0
# 975                                       0
#
#      value__permutation_entropy__dimension_3__tau_1  \
# 0                                                30
# 643                                              30
# 644                                              30
# 645                                              30
# 646                                              30
# ..                                              ...
# 330                                              30
# 331                                              30
# 332                                              30
# 334                                              30
# 975                                              30
#
#      value__permutation_entropy__dimension_4__tau_1  \
# 0                                                 0
# 643                                               0
# 644                                               0
# 645                                               0
# 646                                               0
# ..                                              ...
# 330                                               0
# 331                                               0
# 332                                               0
# 334                                               0
# 975                                               0
#
#      value__permutation_entropy__dimension_5__tau_1  \
# 0                                                 0
# 643                                               0
# 644                                               0
# 645                                               0
# 646                                               0
# ..                                              ...
# 330                                               0
# 331                                               0
# 332                                               0
# 334                                               0
# 975                                               0
#
#      value__permutation_entropy__dimension_6__tau_1  \
# 0                                                 0
# 643                                               0
# 644                                               0
# 645                                               0
# 646                                               0
# ..                                              ...
# 330                                               0
# 331                                               0
# 332                                               0
# 334                                               0
# 975                                               0
#
#      value__permutation_entropy__dimension_7__tau_1  \
# 0                                                 0
# 643                                               0
# 644                                               0
# 645                                               0
# 646                                               0
# ..                                              ...
# 330                                               0
# 331                                               0
# 332                                               0
# 334                                               0
# 975                                               0
#
#      value__mean_n_absolute_max__number_of_maxima_7
# 0                                                 0
# 643                                               0
# 644                                               0
# 645                                               0
# 646                                               0
# ..                                              ...
# 330                                               0
# 331                                               0
# 332                                               0
# 334                                               0
# 975                                               0
#
# [976 rows x 327 columns]
